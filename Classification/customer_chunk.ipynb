# %%
# impport libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import re
import nltk

# %%
# load data
data = pd.read_csv("D:/D/Machine Learning/data/Classification/Customer Chunk/customer_chunk.csv")
data.head(5)
# Out:
#   CustomerID  Gender SeniorCitizen Partner Dependents  Age         City  \
# 0  CUST02497  Female           Yes     Yes         No   87  Los Angeles
# 1  CUST03898    Male            No      No         No   84     New York
# 2  CUST02000    Male            No     Yes        Yes   88      Phoenix
# 3  CUST02066  Female            No     Yes         No   26  Los Angeles
# 4  CUST00884  Female            No      No        Yes   48      Phoenix
#
#    PostalCode  Tenure        Contract  ...     MultipleLines InternetService  \
# 0       10001      43  Month-to-month  ...  No phone service              No
# 1       10001      44  Month-to-month  ...  No phone service              No
# 2       77001      54  Month-to-month  ...                No              No
# 3       10001      23  Month-to-month  ...  No phone service              No
# 4       10001      44  Month-to-month  ...               Yes              No
#
#         OnlineSecurity         OnlineBackup     DeviceProtection  \
# 0                   No                   No  No internet service
# 1  No internet service                  Yes  No internet service
# 2                  Yes  No internet service  No internet service
# 3                  Yes                   No                   No
# 4  No internet service  No internet service  No internet service
#
#            TechSupport          StreamingTV      StreamingMovies Churn  \
# 0                  Yes                   No  No internet service    No
# 1  No internet service  No internet service  No internet service   Yes
# 2                  Yes  No internet service  No internet service    No
# 3  No internet service                   No                   No    No
# 4                   No                   No  No internet service    No
#
#   TotalCharges
# 0      4926.94
# 1      3898.84
# 2      4775.22
# 3      1136.89
# 4      2216.72
#
# [5 rows x 23 columns]

# %%
# check the type of the data
data.dtypes
# Out:
# CustomerID          object
# Gender              object
# SeniorCitizen       object
# Partner             object
# Dependents          object
# Age                  int64
# City                object
# PostalCode           int64
# Tenure               int64
# Contract            object
# PaperlessBilling    object
# PaymentMethod       object
# MonthlyCharges      object
# MultipleLines       object
# InternetService     object
# OnlineSecurity      object
# OnlineBackup        object
# DeviceProtection    object
# TechSupport         object
# StreamingTV         object
# StreamingMovies     object
# Churn               object
# TotalCharges        object
# dtype: object

# %%
# check null values and remove it
data = data.dropna()
data.isnull().sum()
# Out:
# CustomerID          0
# Gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# Age                 0
# City                0
# PostalCode          0
# Tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# TotalCharges        0
# dtype: int64

# %%
# convert object number into int
data['TotalCharges'] = data['TotalCharges'].apply(lambda x: int(float(x)) if str(x).strip().replace('.', '', 1).isdigit() else np.nan)
data.head(1)
# Out:
#   CustomerID  Gender SeniorCitizen Partner Dependents  Age         City  \
# 0  CUST02497  Female           Yes     Yes         No   87  Los Angeles
#
#    PostalCode  Tenure        Contract  ...     MultipleLines InternetService  \
# 0       10001      43  Month-to-month  ...  No phone service              No
#
#   OnlineSecurity OnlineBackup     DeviceProtection TechSupport StreamingTV  \
# 0             No           No  No internet service         Yes          No
#
#        StreamingMovies Churn TotalCharges
# 0  No internet service    No       4926.0
#
# [1 rows x 23 columns]

# %%
# processign object data
column_object = data.select_dtypes(include=['object']).columns
column_object
# Out:
# Index(['CustomerID', 'Gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'City', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Churn'],
#       dtype='object')

# %%
stop_word = set(stopwords.words('english'))
def remove_stopword(txt):
    word_token = word_tokenize(str(txt).lower())
    flt = [word for word in word_token if word.isalpha() and word not in stop_word]
    return " ".join(flt)

def cleaning_text(data):
    dum_data = data
    column_object = dum_data.select_dtypes(include=['object']).columns
    
    # Normalizae text
    for i in column_object:
        dum_data[i] = dum_data[i].str.lower()
        dum_data[i] = dum_data[i].str.strip()

    # Remove punctuation
    for i in column_object:
        dum_data[i] = data[i].str.replace(r'[^\w\s]', '', regex=True)

    # Stop word function
    for i in column_object:
        dum_data[i] = dum_data[i].apply(remove_stopword)
    return dum_data

data = cleaning_text(data)
data =data.dropna()
data.head(3)
# Out:
#   CustomerID  Gender SeniorCitizen Partner Dependents  Age         City  \
# 0             female           yes     yes              87  los angeles
# 1               male                                    84     new york
# 2               male                   yes        yes   88      phoenix
#
#    PostalCode  Tenure      Contract  ...  MultipleLines InternetService  \
# 0       10001      43  monthtomonth  ...  phone service
# 1       10001      44  monthtomonth  ...  phone service
# 2       77001      54  monthtomonth  ...
#
#      OnlineSecurity      OnlineBackup  DeviceProtection       TechSupport  \
# 0                                      internet service               yes
# 1  internet service               yes  internet service  internet service
# 2               yes  internet service  internet service               yes
#
#         StreamingTV   StreamingMovies Churn TotalCharges
# 0                    internet service             4926.0
# 1  internet service  internet service   yes       3898.0
# 2  internet service  internet service             4775.0
#
# [3 rows x 23 columns]
